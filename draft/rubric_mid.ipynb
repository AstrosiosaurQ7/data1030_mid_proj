# %% [markdown]
# ## Project
# - look for datasets on the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/index.php), on [Kaggle](https://www.kaggle.com/), or google's [dataset search engine](https://datasetsearch.research.google.com/).
# - Bring your own dataset!
#    - if you have your own dataset you'd like to work with, this is the perfect opportunity!
# - Avoid the most popular datasets!
#    - no Titanic, no iris for example
# - avoid these four datasets because we will use them in class and you'll work with them in the problem sets
#    - [adult dataset](https://archive.ics.uci.edu/ml/datasets/Adult)
#    - [kaggle house price dataset](https://www.kaggle.com/c/house-prices-advanced-regression-techniques/overview)
#    - [hand postures dataset](https://archive.ics.uci.edu/ml/datasets/Motion+Capture+Hand+Postures)
#    - [diabetes dataset](https://scikit-learn.org/stable/datasets/index.html#diabetes-dataset)
# - work on a classification or regression problem!
# - start looking for datasets now and talk to the TAs or come to my office hours if you have questions!

# %% [markdown]
# ## Other course resources
# - Ed discussion: course forum
#     - feel free to discuss any questions or concerns regarding the material
#     - please post publicly whenever possible (but you can still post anonymously)
#         - if you have a question, it is likely that multiple students have the same question
#     - the TAs and I will keep an eye on it and answer questions in a timely manner
#     - disclaimer: I turn off my laptop after 5pm and during the weekends
# - office hours (TAs and mine)
#     - see the course google calendar
# - An Introduction to Statistical Learning ([book](https://www.statlearning.com/))
# - Introduction to Machine Learning with Python ([book](https://www.amazon.com/Introduction-Machine-Learning-Python-Scientists/dp/1449369413))
# - Harry Potter and the Methods of Rationality ([fan fiction](http://www.hpmor.com/) by Eliezer Yudkowski)
#     - half joking, half serious about this one :)

# %% [markdown]
# ### Midterm project presentation
# The purpose of the semester-long project is to give you hands-on experience working with the machine learning pipeline. For the midterm presentation, you should be done with EDA, splitting, and preprocessing.
#
# The project presentations are on October 17-18-19 in-person, the exact time slots are tbd but we will send out a google sheet to sign up a week before the presentations. We will have six 2-hour sessions set aside. You will have 6 minutes to present, 2-3 minutes for questions, and 1 min to change speakers. Please make sure to be present for your whole session on the day you present so you can listen to your fellow students’ presentations and we encourage you to ask questions.
#
# Please show the draft of your slides to your TA mentor a couple of days before the presentations.
#
# The presentation is basically a quick walk-through of your report.
# Requirements
#
# 1、Title slide (1 point)
# Your title slide should include the title of your presentation, your name, institute, the date of your presentation, and a link to your GitHub repository.
#
# 2、Intro slide (2 points)
# Basically summarize the report’s intro section. The intro slide should explain the problem you want to solve, why this is important, is it regression or classification, and where you got the data from.
#
# 3、EDA slide(s) (7 points)
# Show us what you think was the most interesting, unexpected, or important insight that you gained during EDA. Present at least three different informative visualization types.
#
# 4、Splitting and preprocessing slide(s) (5 points)
# Describe briefly how you split the data and why. What preprocessors did you use and why? How many features and data points you have after preprocessing, did you have missing values and if you did how did you deal with them.
#
# 5、Keep your time (you have a 30 sec grace period but we will deduct 3 points for every minute you go overtime; we round up to the minute)
# Please practice your presentation out loud at least once and make sure you can fit everything into 6 minutes. Moderators in conferences usually do not let you go over time. They will make noise, come to the stage and stand next to you looking at you, or try to signal in other ways that it’s time to wrap up. It is rude to go overtime and delay the presentations of others.
#
# Make sure your slides are not too busy! Your slides should not contain full sentences or paragraphs, only your key points as phrases. Large images and short text is the way to go.
#
# Make sure the figures are readable from a distance! If the text on your figures is too small, your audience won’t be able to see what’s on your figure.
#
# There is no need to add everything to your slides. We will record your presentation and grade what you say as well.
#
# Make sure to speak out loud and with a good pace (don’t rush), and keep eye contact with your audience. A good presentation is about story-telling and engaging your audience. If you feel compelled to speak fast and rush so you can go through all of your slides in time, don’t. Less is more. Cut out a slide or two to save time. If you feel compelled to read from your slides or from your notes, don’t. Most audiences are annoyed by this.

# %% [markdown]
# ### Rubric: Midterm Project Report
# The purpose of the semester-long project is to give you hands-on experience working with the machine learning pipeline. For the first stage of the project, we would like you to identify your guiding question, find the dataset you plan to use to answer the question, perform exploratory data analysis, split the dataset, and perform preprocessing using pandas, matpotlib, and sklearn. Your proposal should be maximum 2 pages, excluding any figures, tables, and references. The report should be similar in style and structure to a research paper.
# Deadline
# Please submit your midterm project report on gradescope by October 21th 5pm (as usual, there is a two-hour grace period until 7pm). We highly encourage you to send your draft report to your assigned TA mentor for review before the submission deadline, so that they can provide you feedback before you turn in the final version on gradescope. The report will be graded by your TA mentor. If you have any questions, please post a question on Ed Discussion or come to the office hours. Please note that if you ask your TA mentor for feedback at the last minute, they might not be able to get back to you because each TA mentors ~13 students. Plan ahead and don’t leave the work to the last minute!
# Requirements
# We describe what sections you should include in your report and what you should describe in those sections. Your goal is to write as if you were writing a scientific publication. Please use the section titles below. This will help the grading process.
#
# Introduction (10 points)
# Clearly describe the problem you want to solve.
# What is the target variable?
# Is the problem regression or classification?
# Why is this interesting/important?
# Number of data points and number of features.
# Add a 1-2 paragraph description or overview of the features.
# Where did the data come from? How was it collected?
# If dataset is not well-documented, write a detailed description for each feature (if feature is categorical, describe each category; if feature is numerical, include the unit of the quantity and what it measures)
# If the dataset is from Kaggle/UCI/already described, do some literature search. Write a short description about 2-3 public projects or publications where the data has been used, what did the authors find, what ML question did they solve and how successful they were (evaluation metric and test scores). The results of the previous work gives you expectation for your ML results.
#
# Exploratory Data Analysis (10 points)
# Perform a thorough EDA on each column in your dataset and pay special attention to your target variable
# Use .describe or .value_counts, create histograms or bar plots as appropriate
# Visualize the target variable. If it’s a classification problem, calculate the balances of each class. If it’s a regression variable, study its distribution.<span style="background-color:yellow"> Any skewness? Outliers? Do the values vary over several orders of magnitudes or just one?
#
# Create other type of figures using two columns
# There is no need to include everything in the report.
# Choose at least three but maximum five figures that you think are interesting or important and one of those figures should show the target variable. Do not include three figures of the same type (e.g., you’ll lose points if you submit three bar plots). Use at least two figure types.
# Write a figure caption for each figure.
# Make sure your figures are publication-quality. Please print out your report before you submit it and make sure the figures are readable, the font size is similar to the text font size, axes are labeled, the figures have sufficient resolution (usually 300 dpi).
#
# Data preprocessing (10 points)
# Discuss how you split the dataset and why.
# Is your dataset IID?
# Does it have group structure?
# Is it time-series data?
# How should you split the dataset given your ML question to best mimic future use when you deploy the model?
# Apply MinMaxEncoder or StandardScaler on the continuous features
# Apply OneHotEncoder or OrdinalEncoder on categorical features
# Describe why you chose a particular preprocessor for each feature.
# How many features do you have in the preprocessed data?
#
# References (2 points)
# Cite previous work and add your citations to the ‘References’ section which should be the last section of your report.
#
# Github repository (3 points)
# Please create a public github repository for your project and include the link in your report.
# For now, there should be three folders in your repository:
# data: download your dataset into this folder.
# figures: any figures you make should be saved in this folder in png, jpg, or pdf format. You can and should have more figures in here than what you have in your report.
# src: your python notebooks should be in this folder. Make sure that your code reads in the data from the data folder and saves the figures directly into the figures folder.

# %% [markdown]
# 酒店房租 https://www.kaggle.com/datasets/ramjasmaurya/oyo-rental-price-prediction-in-china/code?select=rental_price.csv
# 学习和酒精https://www.kaggle.com/datasets/whenamancodes/alcohol-effects-on-study

# %% [markdown]
# Hi everyone,
#
# Please carefully read this admittedly long post about the schedule for the midterm week.
#
# The midterm presentations will be on October 17th 9am-11am and 1-3pm, October 18th 10am-noon and 3-5pm, and October 19th 9-11am and 1-3pm. Here is the sign up sheet. Put your name and email to your preferred 10 minute slot. Reservations are on a first come first serve basis.
#
# It's not nice if you just show up for your 10 min slot and then leave. So only sign up to a slot if you can attend the whole 2 hour session. Also note that you might present sooner than your slot. If there are empty slots before yours, we will not wait around for 10 minutes. Instead you will start sooner. So that's another reason why you are required to attend the whole 2 hour session.
#
# All presentations will take place in the DSI open space (3rd floor of 164 Angell street). Lunch will be served on October 17-18-19 from noon to 1pm to all presenters of the day in the DSI open space so please join me and the TAs there. Everyone is encouraged to attend any and all of the sessions to cheer your fellow classmates on and to ask questions.
#
# If you cannot attend in person for some reason (due to e.g., illness), reach out to me as soon as possible.
#
# The rubrics for the presentation and the report are available here.
#
# TA mentors:
#
# Most of you met with your TA mentor by now. If you need additional help, email or try to meet with your TA mentor by 5pm October 14th the latest. Work-life balance is important and they are not required to answer emails after 5pm or during the weekend. So plan accordingly because last minute requests e.g., on October 15th and 16th (Saturday and Sunday) might go unanswered until Monday.
#
# Gradescope:
#
# You will need to submit your slides in pdf format to gradescope by October 19th 5pm, and you will need to submit your midterm report also in pdf format by October 21st 5pm. I'll add the assignments to gradescope in the coming days with the deadlines.
#
# Lectures:
#
# The lecture on October 18th is cancelled and we will have a guest lecturer on October 20th so we will not cover new materials during the midterm week. I'll send out a separate announcement about the guest lecture some time next week.
#
# Problem sets:
#
# I will not release PS6 on October 12th which means no problem set will be due by October 19th. I hope this will help you to spend more time on your projects. PS6 will be released on October 19th though and it will be due by October 26th.
#
# Office hours:
#
# I'll keep my usual instructor office hours on October 17th 2-4pm so you can stop by my office if you have any last minute questions related to your project. The TA office hours will be on October 20th 3-5pm in room 375, and October 21st 2-4pm in room 320. So you can ask the TAs about the midterm report or PS6 during that time.
#
# We will be back to normal course schedule starting October 24th until the Thanksgiving break.
#
# I wish you all good luck during the midterm week! I am looking forward to your presentations and reports. Getting to know a bit more about your interests and projects is my favorite part of DATA1030.
#
# If you have any questions/concerns, reply to this post.
#
# Have a great weekend!
#
# Andras
